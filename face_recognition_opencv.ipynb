# %% [markdown]
# Getting the pre-trained model of CV2

# %%
# !wget https://github.com/kipr/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml

# %% [markdown]
# Getting some pictures test the model

# %%
# !wget https://assets.weforum.org/article/image/XaHpf_z51huQS_JPHs-jkPhBp0dLlxFJwt-sPLpGJB0.jpg
# !wget https://static.onecms.io/wp-content/uploads/sites/20/2020/12/01/12-14-2020-tout.jpg

# %% [markdown]
# Installing the necessary packages

# %%
# !pip install opencv-python --upgrade
# !pip install matplotlib --upgrade

# %%
import cv2
from matplotlib import pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
#image = cv2.imread('/content/XaHpf_z51huQS_JPHs-jkPhBp0dLlxFJwt-sPLpGJB0.jpg')
image = cv2.imread('/content/12-14-2020-tout.jpg')

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
detect_faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=3,flags=cv2.CASCADE_SCALE_IMAGE)

# %%
print(f'the number of faces in the image is, ', {len(detect_faces)})
# Out:
# the number of faces in the image is,  {5}

# %%
for(x,y,w,h) in detect_faces:
  cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0),2)

plt.imshow(image)
plt.title('my picture')
plt.show()
